# %%
from astropy.io import fits
from astropy.wcs import WCS
import matplotlib.pyplot as plt
import numpy as np

# %%
example = fits.open("/Users/seanhess/Data/level2/generated/pid_1_118/inv.SD9T3L/INV_SD9T3L_2022_06_02T22_10_11_205_L2.fits")
example[1].data.shape
# Out:
# (1, 237, 81)

# %%
opticalDepth = example[1]
temperature = example[2]
velocity = example[5]

wcs = WCS(temperature.header)
wcs[0]
#print(temp_wcs)
#plt.plot(temperature.data)

ax = plt.subplot(projection=wcs, slices=(0,'x','y'))
ax.imshow(temperature.data[0,:,:])
#ax.imshow(example[2].data[:,:,:])

# %%
image = temperature[0,:,:]##.transpose()
print(image.shape)

#plt.figure(figsize=(10, 10))
ax = plt.subplot(projection=wcs, slices=(0, 'x', 'y'))

#print(ax.coords)

#stokes, wav, hplt, hpln = ax.coords

#wav.set_format_unit(u.nm)
#wav.set_major_formatter('x.x')

#ax.imshow(image)
# Out:
# (237, 81)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 5
#       2 print(image.shape)
#       4 #plt.figure(figsize=(10, 10))
# ----> 5 ax = plt.subplot(projection=wcs, slices=(0, 'x', 'y'))
#       7 #print(ax.coords)
#       8
#       9 #stokes, wav, hplt, hpln = ax.coords
#    (...)
#      13
#      14 #ax.imshow(image)
#
# File ~/.pyenv/versions/3.10.5/envs/notebooks/lib/python3.10/site-packages/matplotlib/pyplot.py:1546, in subplot(*args, **kwargs)
#    1543         break
#    1544 else:
#    1545     # we have exhausted the known Axes and none match, make a new one!
# -> 1546     ax = fig.add_subplot(*args, **kwargs)
#    1548 fig.sca(ax)
#    1550 return ax
#
# File ~/.pyenv/versions/3.10.5/envs/notebooks/lib/python3.10/site-packages/matplotlib/figure.py:710, in FigureBase.add_subplot(self, *args, **kwargs)
# ...

# %% [markdown]
# ## Bad Data with Zeros in it

# %%
bad = fits.open("/Users/seanhess/Data/level2/generated/pid_1_118/inv.GSFF9N/INV_GSFF9N_2022_06_02T21_55_10_176_L2.fits")
bad.info()
# Out:
# Filename: /Users/seanhess/Data/level2/generated/pid_1_118/inv.EGH11D/INV_EGH11D_2022_06_02T22_14_14_548_L2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      76   ()
#   1  Log of Optical Depth at 500nm    1 ImageHDU        69   (81, 237, 1)   float32
#   2  Temperature    1 ImageHDU        69   (81, 237, 1)   float32
#   3  Electron Pressure    1 ImageHDU        69   (81, 237, 1)   float32
#   4  Microturbulence    1 ImageHDU        69   (81, 237, 1)   float32
#   5  Magnetic Field Strength    1 ImageHDU        69   (81, 237, 1)   float32
#   6  Line-of-sight Velocity    1 ImageHDU        69   (81, 237, 1)   float32
#   7  Magnetic Field Inclination (w.r.t. line-of-sight)    1 ImageHDU        69   (81, 237, 1)   float32
#   8  Magnetic Field Azimuth (w.r.t. line-of-sight)    1 ImageHDU        69   (81, 237, 1)   float32
# ...

# %%
bad = fits.open("/Users/seanhess/Data/level2/generated/pid_1_118/inv.GSFF9N/INV_GSFF9N_2022_06_02T21_55_10_176_L2.fits")
plt.imshow(bad[2].data[0,:,:], vmin=0, vmax=8000)

# %%
prev = fits.open("/Users/seanhess/Data/level2/generated/pid_1_118/inv.GSFF9N/INV_GSFF9N_2022_06_02T21_55_06_888_L2.fits")
plt.imshow(prev[2].data[0,:,:], vmin=0, vmax=8000)

# %%
next = fits.open("/Users/seanhess/Data/level2/generated/pid_1_118/inv.GSFF9N/INV_GSFF9N_2022_06_02T21_55_13_464_L2.fits")
plt.imshow(next[2].data[0,:,:], vmin=0, vmax=8000)
